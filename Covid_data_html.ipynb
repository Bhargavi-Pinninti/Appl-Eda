# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavi-Pinninti/Appl-Eda/blob/main/Covid_data_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/covid data/WHO COVID-19 global table data August 11th 2021 at 10.41.34 AM (1).csv')

# %%
data
# Out:
#                                      Name  ...  Deaths - newly reported in last 24 hours
# Global                                NaN  ...                                       NaN
# United States of America         Americas  ...                                       NaN
# India                     South-East Asia  ...                                       NaN
# Brazil                           Americas  ...                                       NaN
# Russian Federation                 Europe  ...                                       NaN
# ...                                   ...  ...                                       ...
# Saint Helena                       Africa  ...                                       NaN
# Tokelau                   Western Pacific  ...                                       NaN
# Tonga                     Western Pacific  ...                                       NaN
# ...

# %%
data.isnull()
# Out:
#                            Name  ...  Deaths - newly reported in last 24 hours
# Global                     True  ...                                      True
# United States of America  False  ...                                      True
# India                     False  ...                                      True
# Brazil                    False  ...                                      True
# Russian Federation        False  ...                                      True
# ...                         ...  ...                                       ...
# Saint Helena              False  ...                                      True
# Tokelau                   False  ...                                      True
# Tonga                     False  ...                                      True
# Turkmenistan              False  ...                                      True
# Tuvalu                    False  ...                                      True
#
# [238 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# Name                                                              1
# WHO Region                                                        0
# Cases - cumulative total                                          1
# Cases - cumulative total per 100000 population                    0
# Cases - newly reported in last 7 days                             1
# Cases - newly reported in last 7 days per 100000 population       0
# Cases - newly reported in last 24 hours                           0
# Deaths - cumulative total                                         1
# Deaths - cumulative total per 100000 population                   0
# Deaths - newly reported in last 7 days                            1
# Deaths - newly reported in last 7 days per 100000 population      0
# Deaths - newly reported in last 24 hours                        238
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#                           WHO Region  ...  Deaths - newly reported in last 7 days per 100000 population
# Global                     203295170  ...                                               8426
# United States of America    35657845  ...                                                556
# India                       31998158  ...                                                373
# Brazil                      20165672  ...                                                399
# Russian Federation           6491288  ...                                                792
# ...                              ...  ...                                                ...
# Saint Helena                       0  ...                                                  0
# Tokelau                            0  ...                                                  0
# Tonga                              0  ...                                                  0
# ...

# %%
data.fillna(method='bfill',axis=0).fillna(0)
# Out:
#                                      Name  ...  Deaths - newly reported in last 24 hours
# Global                           Americas  ...                                       0.0
# United States of America         Americas  ...                                       0.0
# India                     South-East Asia  ...                                       0.0
# Brazil                           Americas  ...                                       0.0
# Russian Federation                 Europe  ...                                       0.0
# ...                                   ...  ...                                       ...
# Saint Helena                       Africa  ...                                       0.0
# Tokelau                   Western Pacific  ...                                       0.0
# Tonga                     Western Pacific  ...                                       0.0
# ...

# %%
sns.heatmap(data.isnull())

# %%
sns.pairplot(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
